# %% [markdown]
# <a href="https://colab.research.google.com/github/FilbertWibowo/PRAKTIKUMM/blob/main/Praktikum_Algoritma_Pemrograman_Minggu_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Say hello to python
# Filbert Wibowo (2440506049)

# %%
print('hello python!')
# Out:
# hello python!

# %%
import sys

# %%
print(sys.version)
# Out:
# 3.10.12 (main, Jul 29 2024, 16:56:48) [GCC 11.4.0]

# %%
print('hello python!')
# Out:
# hello python!

# %%
print('Hello, Python!')
# ini komen
# Out:
# Hello, Python!

# %%
frint ("hello python")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-25c8469a0258> in <cell line: 1>()
# ----> 1 frint ("hello python")
#
# NameError: name 'frint' is not defined

# %%
print("Hello, Python!)
# Out:
#   File "<ipython-input-8-c10a1b330477>", line 1
#     print("Hello, Python!)
#           ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
print("ini bisa terprint")
frint("ini akan name error")
print("ini tidak terprint")
# Out:
# ini bisa terprint
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-303a2ecbca41> in <cell line: 2>()
#       1 print("ini bisa terprint")
# ----> 2 frint("ini akan name error")
#       3 print("ini tidak terprint")
#
# NameError: name 'frint' is not defined

# %% [markdown]
# # TUGAS 1

# %%
print ('Nama : Filbert Wibowo')
print ('NPM : 2440506049')
print ('Alamat : Tambakan, Sedayu, Muntilan, Magelang, Jawa Tengah')
print ('Tinggi Badan : 160')
print ('Berat Badan : 64')
# Out:
# Nama : Filbert Wibowo
# NPM : 2440506049
# Alamat : Tambakan, Sedayu, Muntilan, Magelang, Jawa Tengah
# Tinggi Badan : 160
# Berat Badan : 64

# %% [markdown]
# # TUGAS 2

# %%
print('\033[1m' + 'UNIVERSITAS TIDAR' + '\033[0m')
print('Universitas Tidar merupakan Perguruan Tinggi Pemerintah atau Perguruan Tinggi Negeri yang telah ditetapkan berdasarkan Peraturan Presiden Republik Indonesia Nomor 23 Tahun 2014 pada tanggal 1 April 2014.')
print('\033[1m' + 'JURUSAN TEKNIK ELEKTRO, MEKATRONIKA DAN INFORMATIKA' + '\033[0m')
print('S1 Teknik Elektro (\x1b[3mBachelor of Electrical Engineering\x1b[0m)')
print('S1 Teknologi Informasi (\x1b[3mBachelor of Information Technology\x1b[0m)')
print('S1 Teknik Mekatronika (\x1b[3mBachelor of Mechatronics Engineering\x1b[0m)')
# Out:
# UNIVERSITAS TIDAR
# Universitas Tidar merupakan Perguruan Tinggi Pemerintah atau Perguruan Tinggi Negeri yang telah ditetapkan berdasarkan Peraturan Presiden Republik Indonesia Nomor 23 Tahun 2014 pada tanggal 1 April 2014.
# JURUSAN TEKNIK ELEKTRO, MEKATRONIKA DAN INFORMATIKA
# S1 Teknik Elektro (Bachelor of Electrical Engineering)
# S1 Teknologi Informasi (Bachelor of Information Technology)
# S1 Teknik Mekatronika (Bachelor of Mechatronics Engineering)

# %%
nama print("namamu")
if
